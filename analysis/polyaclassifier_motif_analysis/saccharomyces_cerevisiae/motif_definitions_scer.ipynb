# %% [markdown]
# # Motif Family Definitions for *S. cerevisiae*

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %run -i notebook_setup.py

# %%
from paper_utilities import motifs

# %%
PROJECT = "/projects/b1080/eks/polyadenylation/yeast"
OUTDIR  = os.path.join(PROJECT, 'manuscript', 'analysis', 'resources')
os.makedirs(OUTDIR, exist_ok = True)

# %% [markdown]
# ## K-mer definitions

# %%
all_4mers = ["".join(x) for x in list(itertools.product('ACGT', repeat = 4))]
all_5mers = ["".join(x) for x in list(itertools.product('ACGT', repeat = 5))]
all_6mers = ["".join(x) for x in list(itertools.product('ACGT', repeat = 6))]

pd.DataFrame.from_dict({'motif' : all_4mers}, orient = 'columns').to_csv(os.path.join(OUTDIR, 'motif_list.4mers.txt'), sep = "\t", index = False, header = False)
pd.DataFrame.from_dict({'motif' : all_5mers}, orient = 'columns').to_csv(os.path.join(OUTDIR, 'motif_list.5mers.txt'), sep = "\t", index = False, header = False)
pd.DataFrame.from_dict({'motif' : all_6mers}, orient = 'columns').to_csv(os.path.join(OUTDIR, 'motif_list.6mers.txt'), sep = "\t", index = False, header = False)

# %% [markdown]
# ## S. cerevisiae

# %%
family_cmap = {
    'A-rich_d0'     : '#2278B5',
    'A-rich_d1'     : '#6AB1E3',
    'A-rich_d2'     : '#9CCBEC',
    'T-rich_d0'     : '#2FA148',
    'T-rich_d1'     : '#73D689',
    'T-rich_d2'     : '#A1E4B0',
    'TA/TA-rich_d0' : '#D62A28',
    'TA/TA-rich_d1' : '#E77F7E',
    'TA/TA-rich_d2' : '#EFAAA9',
    'Other'         : '#F7F8F8',
}

# %% [markdown]
# ### By pattern

# %%
## Identify motif patterns

variants = ['TATAAA', 'AGTAAA', 'TTTAAA', 'AATACA', 'CATAAA', 'GATAAA', 'AATATA', 'AATGAA', 'AAGAAA']

tata_patterns = ['TATA','ATAT']
tgta_patterns = ['TGTA','ATGT','TATG','GTAT','GATA','ATAG','TAGA','AGAT']
tcta_patterns = ['TCTA','ATCT','TATC','CTAT','CATA','ATAC','TACA','ACAT']
taaa_patterns = ['TAAA','AAAT','ATAA','AATA']
ttaa_patterns = ['TTAA','AATT']
gt_patterns   = ['GTGT','TGTG','GTCT','CTGT','TCTG','TGTC']


## Assign motifs to families based on priority

a_rich = list(set([x for x in all_6mers if x.count('A') >= 4]))
t_rich = list(set([x for x in all_6mers if x.count('T') >= 4]))
g_rich = list(set([x for x in all_6mers if x.count('G') >= 4]))

tata_rich = list(set([x for x in all_6mers for p in tata_patterns if (p in x)]))
tgta_rich = list(set([x for x in all_6mers for p in tgta_patterns if (p in x)]))
tcta_rich = list(set([x for x in all_6mers for p in tcta_patterns if (p in x)]))
taaa_rich = list(set([x for x in all_6mers for p in taaa_patterns if (p in x)]))
ttaa_rich = list(set([x for x in all_6mers for p in ttaa_patterns if (p in x)]))
gt_rich   = list(set([x for x in all_6mers for p in gt_patterns if ((p in x) and ("TGTA" not in x))]))

ta_rich = list(set([x for x in all_6mers if ((x.count('A') >= 3) and (x.count('T') >= 2)) or ((x.count('T') >= 3) and (x.count('A') >= 2))]))


## Assign motifs to families based on priority

motif_priority = {
    'G-rich'      : g_rich,
    'G/T-rich'    : gt_rich,
    'T/A-rich'    : ta_rich,
    'A-rich'      : a_rich,
    'T-rich'      : t_rich,
    'TT/AA-rich'  : ttaa_rich,
    'TA/AA-rich'  : taaa_rich,
    'TC/TA-rich'  : tcta_rich,
    'TG/TA-rich'  : tgta_rich,
    'TA/TA-rich'  : tata_rich,
}

motif_family = {}

for motif in all_6mers:
    motif_family[motif] = 'Other'
    
for mf,mlist in motif_priority.items():
    for m in mlist:
        motif_family[m] = mf

        
## Output list of motifs in each family for use in R

motif_unique = {}

for mf in motif_priority.keys():
    motif_unique[mf] = sorted([k for k,v in motif_family.items() if (v == mf)])
    print(mf, "\t", len(motif_unique[mf]))
    
for mf,ml in motif_unique.items():
    outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
    print(outstring)


## Record motif family definitions

pattern_definitions = {
    'priority'   : motif_priority,
    'family'     : motif_family,
    'no_overlap' : motif_unique,
}

with open(os.path.join(OUTDIR, 'motif_definitions.scer.6mers.patterns.pickle'), mode = 'wb') as handle:
    pickle.dump(pattern_definitions, handle)

(pd.DataFrame.from_dict(motif_family, orient = 'index').reset_index()
 .rename(columns = {'index' : 'motif', 0 : 'family'})
 .to_csv(os.path.join(OUTDIR, 'motif_families.scer.6mers.patterns.txt'))
)
# Out:
# G-rich 	 150
# G/T-rich 	 164
# T/A-rich 	 56
# A-rich 	 89
# T-rich 	 129
# TT/AA-rich 	 76
# TA/AA-rich 	 106
# TC/TA-rich 	 250
# TG/TA-rich 	 286
# TA/TA-rich 	 80
#
# g_rich <- c('AAGGGG', 'ACGGGG', 'AGAGGG', 'AGCGGG', 'AGGAGG', 'AGGCGG', 'AGGGAG', 'AGGGCG', 'AGGGGA', 'AGGGGC', 'AGGGGG', 'AGGGGT', 'AGGGTG', 'AGGTGG', 'AGTGGG', 'ATGGGG', 'CAGGGG', 'CCGGGG', 'CGAGGG', 'CGCGGG', 'CGGAGG', 'CGGCGG', 'CGGGAG', 'CGGGCG', 'CGGGGA', 'CGGGGC', 'CGGGGG', 'CGGGGT', 'CGGGTG', 'CGGTGG', 'CGTGGG', 'CTGGGG', 'GAAGGG', 'GACGGG', 'GAGAGG', 'GAGCGG', 'GAGGAG', 'GAGGCG', 'GAGGGA', 'GAGGGC', 'GAGGGG', 'GAGGGT', 'GAGGTG', 'GAGTGG', 'GATGGG', 'GCAGGG', 'GCCGGG', 'GCGAGG', 'GCGCGG', 'GCGGAG', 'GCGGCG', 'GCGGGA', 'GCGGGC', 'GCGGGG', 'GCGGGT', 'GCGGTG', 'GCGTGG', 'GCTGGG', 'GGAAGG', 'GGACGG', 'GGAGAG', 'GGAGCG', 'GGAGGA', 'GGAGGC', 'GGAGGG', 'GGAGGT', 'GGAGTG', 'GGATGG', 'GGCAGG', 'GGCCGG', 'GGCGAG', 'GGCGCG', 'GGCGGA', 'GGCGGC', 'GGCGGG', 'GGCGGT', 'GGCGTG', 'GGCTGG', 'GGGAAG
 'TATCGG', 'TATCGT', 'TATCTA', 'TATCTC', 'TATCTG', 'TATCTT', 'TCACAT', 'TCATAA', 'TCATAC', 'TCATCT', 'TCCATA', 'TCCTAT', 'TCTAAA', 'TCTAAC', 'TCTAAG', 'TCTAAT', 'TCTACA', 'TCTACC', 'TCTACG', 'TCTACT', 'TCTAGC', 'TCTAGG', 'TCTAGT', 'TCTATC', 'TCTATT', 'TCTCTA', 'TGACAT', 'TGATCT', 'TGCATA', 'TGCTAT', 'TGTCTA', 'TTACAA', 'TTACAC', 'TTACAG', 'TTACAT', 'TTATCA', 'TTATCC', 'TTATCG', 'TTATCT', 'TTCATA', 'TTCTAA', 'TTCTAC', 'TTCTAG', 'TTCTAT', 'TTTACA', 'TTTATC', 'TTTCTA')
#
# tgta_rich <- c('AAAGAT', 'AAATAG', 'AAATGT', 'AAGATA', 'AAGATC', 'AAGATG', 'AAGATT', 'AAGTAT', 'AATAGA', 'AATAGC', 'AATAGG', 'AATAGT', 'AATGTA', 'AATGTC', 'AATGTG', 'AATGTT', 'ACAGAT', 'ACATAG', 'ACATGT', 'ACGATA', 'ACGTAT', 'ACTAGA', 'ACTATG', 'ACTGTA', 'AGAGAT', 'AGATAA', 'AGATAC', 'AGATAG', 'AGATCA', 'AGATCC', 'AGATCG', 'AGATCT', 'AGATGA', 'AGATGC', 'AGATGG', 'AGATGT', 'AGATTA', 'AGATTC', 'AGATTG', 'AGATTT', 'AGGATA', 'AGGTAT', 'AGTAGA', 'AGTATC', 'AGTATG', 'AGTATT', 'AGTGTA', 'ATAGAA', 'ATAGAC', 'ATAGAG', 'ATAGAT', 'ATAGCA', 'ATAGCC', 'ATAGCG', 'ATAGCT', 'ATAGGA', 'ATAGGC', 'ATAGGG', 'ATAGGT', 'ATAGTA', 'ATAGTC', 'ATAGTG', 'ATAGTT', 'ATGATA', 'ATGTAA', 'ATGTAC', 'ATGTAG', 'ATGTAT', 'ATGTCA', 'ATGTCC', 'ATGTCG', 'ATGTCT', 'ATGTGA', 'ATGTGC', 'ATGTGG', 'ATGTGT', 'ATGTTA', 'ATGTTC', 'ATGTTG', 'ATGTTT', 'ATTAGA', 'ATTATG', 'ATTGTA', 'CAAGAT', 'CAATAG', 'CAATGT', 'CAGATA', 'CAGATC', 'CAGATG', 'CAGATT', 'CAGTAT', 'CATAGA', 'CATAGC', 'CATAGG', 'CATAGT', 'CATGTA', 'CATGTC', 'CATGTG', 'CATGTT', 'CCAGAT', 'CCATAG', 'CCATGT', 'CCGATA', 'CCGTAT', 'CCTAGA', 'CCTATG', 'CCTGTA', 'CGAGAT', 'CGATAA', 'CGATAC', 'CGATAG', 'CGATGT', 'CGGATA', 'CGGTAT', 'CGTAGA', 'CGTATC', 'CGTATG', 'CGTATT', 'CGTGTA', 'CTAGAA', 'CTAGAC', 'CTAGAG', 'CTAGAT', 'CTATGA', 'CTATGC', 'CTATGG', 'CTATGT', 'CTGATA', 'CTGTAA', 'CTGTAC', 'CTGTAG', 'CTGTAT', 'CTTAGA', 'CTTATG', 'CTTGTA', 
', 'CTATAC', 'CTATAG', 'CTATAT', 'CTTATA', 'GAATAT', 'GATATA', 'GATATC', 'GATATG', 'GATATT', 'GCATAT', 'GCTATA', 'GGATAT', 'GGTATA', 'GTATAA', 'GTATAC', 'GTATAG', 'GTATAT', 'GTTATA', 'TAATAT', 'TATAAA', 'TATAAC', 'TATAAG', 'TATAAT', 'TATACA', 'TATACC', 'TATACG', 'TATACT', 'TATAGA', 'TATAGC', 'TATAGG', 'TATAGT', 'TATATA', 'TATATC', 'TATATG', 'TATATT', 'TCATAT', 'TCTATA', 'TGATAT', 'TGTATA', 'TTATAA', 'TTATAC', 'TTATAG', 'TTATAT', 'TTTATA')

# %% [markdown]
# ### By Hamming distance to archetypical motifs

# %% [markdown]
# #### 6 mers

# %%
## Identify archetypical motifs and assign motifs to their most similar archetype

archetypes = np.asarray(['TATATA','ATATAT','AAAAAA','TTTTTT'])

closest_family,closest_distance,closest_matches = zip(*[motifs.closest_archetype(motif, archetypes, kmer=6, max_mismatch=2) for motif in all_6mers])
closest_family   = np.asarray(closest_family)
closest_distance = np.asarray(closest_distance, dtype = float)

ambiguous_motifs = [h for h,m in zip(all_6mers, closest_matches) if len(m) > 1]


## Define family of TA/TA-rich motifs

fam_tatata_d0 = sorted(np.asarray(all_6mers)[((closest_family == 'TATATA') | (closest_family == 'ATATAT')) & (closest_distance == 0)].tolist())
fam_tatata_d1 = sorted(np.asarray(all_6mers)[((closest_family == 'TATATA') | (closest_family == 'ATATAT')) & (closest_distance == 1)].tolist())
fam_tatata_d2 = sorted(np.asarray(all_6mers)[((closest_family == 'TATATA') | (closest_family == 'ATATAT')) & (closest_distance == 2)].tolist())

print(len(fam_tatata_d0), fam_tatata_d0[:5])
print(len(fam_tatata_d1), fam_tatata_d1[:5])
print(len(fam_tatata_d2), fam_tatata_d2[:5])


## Define family of A-rich motifs

fam_a_rich_d0 = sorted(np.asarray(all_6mers)[(closest_family == 'AAAAAA') & (closest_distance == 0)].tolist())
fam_a_rich_d1 = sorted(np.asarray(all_6mers)[(closest_family == 'AAAAAA') & (closest_distance == 1)].tolist())
fam_a_rich_d2 = sorted(np.asarray(all_6mers)[(closest_family == 'AAAAAA') & (closest_distance == 2)].tolist())

print(len(fam_a_rich_d0), fam_a_rich_d0[:5])
print(len(fam_a_rich_d1), fam_a_rich_d1[:5])
print(len(fam_a_rich_d2), fam_a_rich_d2[:5])


## Define family of T-rich motifs

fam_t_rich_d0 = sorted(np.asarray(all_6mers)[(closest_family == 'TTTTTT') & (closest_distance == 0)].tolist())
fam_t_rich_d1 = sorted(np.asarray(all_6mers)[(closest_family == 'TTTTTT') & (closest_distance == 1)].tolist())
fam_t_rich_d2 = sorted(np.asarray(all_6mers)[(closest_family == 'TTTTTT') & (closest_distance == 2)].tolist())

print(len(fam_t_rich_d0), fam_t_rich_d0[:5])
print(len(fam_t_rich_d1), fam_t_rich_d1[:5])
print(len(fam_t_rich_d2), fam_t_rich_d2[:5])


## Assign motifs to families based on priority

motif_priority = {
    
    'A-rich_d0'   : sorted(fam_a_rich_d0),
    'A-rich_d1'   : sorted(fam_a_rich_d1),
    'A-rich_d2'   : sorted(fam_a_rich_d2),
    'A-rich'      : sorted(fam_a_rich_d0 + fam_a_rich_d1 + fam_a_rich_d2),

    'T-rich_d0'   : sorted(fam_t_rich_d0),
    'T-rich_d1'   : sorted(fam_t_rich_d1),
    'T-rich_d2'   : sorted(fam_t_rich_d2),
    'T-rich'      : sorted(fam_t_rich_d0 + fam_t_rich_d1 + fam_t_rich_d2),
    
    'TA/TA-rich_d0' : sorted(fam_tatata_d0),
    'TA/TA-rich_d1' : sorted(fam_tatata_d1),
    'TA/TA-rich_d2' : sorted(fam_tatata_d2),
    'TA/TA-rich'    : sorted(fam_tatata_d0 + fam_tatata_d1 + fam_tatata_d2),
    
}

motif_family = {}
motif_hamming = {}

for motif in all_6mers:
    motif_family[motif] = 'Other'
    
for mf,mlist in motif_priority.items():
    for m in mlist:
        motif_family[m] = mf

for mf,mlist in motif_priority.items():
    for m in mlist:
        if ("_d") in mf:
            motif_hamming[m] = mf

            
## Output list of motifs in each family for use in R

motif_unique = {}

for mf in motif_priority.keys():
    motif_unique[mf] = sorted([k for k,v in motif_family.items() if (v == mf)])
    if ("_d" not in mf):
        print(mf, "\t", len(motif_unique[mf]))
    
for mf,ml in motif_unique.items():
    if ("_d" not in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)

for mf,ml in motif_priority.items():
    if ("_d" in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)


## Record motif family definitions

hamming_definitions = {
    'priority'   : motif_priority,
    'family'     : motif_family,
    'no_overlap' : motif_unique,
    'hamming'    : motif_hamming,
}

with open(os.path.join(OUTDIR, 'motif_definitions.scer.6mers.distance.pickle'), mode = 'wb') as handle:
    pickle.dump(hamming_definitions, handle)

(pd.DataFrame.from_dict(motif_family, orient = 'index').reset_index()
 .rename(columns = {'index' : 'motif', 0 : 'family'})
 .to_csv(os.path.join(OUTDIR, 'motif_families.scer.6mers.distance.txt'))
)
# Out:
# Conflicting family assignment: AAACAT equidistant to ['ATATAT' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: AAAGAT equidistant to ['ATATAT' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: AAATAC equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: AAATAG equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: AACATA equidistant to ['TATATA' 'AAAAAA'] ... assigning to TATATA based on priority
# Conflicting family assignment: AAGATA equidistant to ['TATATA' 'AAAAAA'] ... assigning to TATATA based on priority
# Conflicting family assignment: AATACA equidistant to ['TATATA' 'AAAAAA'] ... assigning to TATATA based on priority
# Conflicting family assignment: AATAGA equidistant to ['TATATA' 'AAAAAA'] ... assigning to TATATA based on priority
# Conflicting family assignment: ACAAAT equidistant to ['ATATAT' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: ACATAA equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: AGAAAT equidistant to ['ATATAT' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: AGATAA equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: ATAAAC equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: ATAAAG equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: ATACAA equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: ATAGAA equidistant to ['ATATAT' 'AAAAAA'] ... assigning to ATATAT based on content
# Conflicting family assignment: ATCTTT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: ATGTTT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: ATTTCT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: ATTTGT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: CAAATA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: CATAAA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: CTATTT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: CTTTAT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: GAAATA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: GATAAA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: GTATTT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: GTTTAT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: TAAACA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: TAAAGA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: TACAAA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: TAGAAA equidistant to ['TATATA' 'AAAAAA'] ... assigning to AAAAAA based on content
# Conflicting family assignment: TATCTT equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TATGTT equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TATTTC equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TATTTG equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TCTATT equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TCTTTA equidistant to ['TATATA' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: TGTATT equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TGTTTA equidistant to ['TATATA' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: TTATCT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to ATATAT based on priority
# Conflicting family assignment: TTATGT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to ATATAT based on priority
# Conflicting family assignment: TTCTAT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to ATATAT based on priority
# Conflicting family assignment: TTGTAT equidistant to ['ATATAT' 'TTTTTT'] ... assigning to ATATAT based on priority
# Conflicting family assignment: TTTATC equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TTTATG equidistant to ['TATATA' 'TTTTTT'] ... assigning to TATATA based on content
# Conflicting family assignment: TTTCTA equidistant to ['TATATA' 'TTTTTT'] ... assigning to TTTTTT based on content
# Conflicting family assignment: TTTGTA equidistant to ['TATATA' 'TTTTTT'] ... assigning to TTTTTT based on content
# 2 ['ATATAT', 'TATATA']
# 36 ['AAATAT', 'AATATA', 'ACATAT', 'AGATAT', 'ATAAAT']
# 234 ['AAATAC', 'AAATAG', 'AAATCT', 'AAATGT', 'AAATTT']
# 1 ['AAAAAA']
# 18 ['AAAAAC', 'AAAAAG', 'AAAAAT', 'AAAACA', 'AAAAGA']
# 117 ['AAAACC', 'AAAACG', 'AAAACT', 'AAAAGC', 'AAAAGG']
# 1 ['TTTTTT']
# 18 ['ATTTTT', 'CTTTTT', 'GTTTTT', 'TATTTT', 'TCTTTT']
# 117 ['AATTTT', 'ACTTTT', 'AGTTTT', 'ATCTTT', 'ATGTTT']
# A-rich 	 136
# T-rich 	 136
# TA/TA-rich 	 272
#
# a_rich <- c('AAAAAA', 'AAAAAC', 'AAAAAG', 'AAAAAT', 'AAAACA', 'AAAACC', 'AAAACG', 'AAAACT', 'AAAAGA', 'AAAAGC', 'AAAAGG', 'AAAAGT', 'AAAATA', 'AAAATC', 'AAAATG', 'AAAATT', 'AAACAA', 'AAACAC', 'AAACAG', 'AAACAT', 'AAACCA', 'AAACGA', 'AAACTA', 'AAAGAA', 'AAAGAC', 'AAAGAG', 'AAAGAT', 'AAAGCA', 'AAAGGA', 'AAAGTA', 'AAATAA', 'AAATCA', 'AAATGA', 'AAATTA', 'AACAAA', 'AACAAC', 'AACAAG', 'AACAAT', 'AACACA', 'AACAGA', 'AACCAA', 'AACGAA', 'AACTAA', 'AAGAAA', 'AAGAAC', 'AAGAAG', 'AAGAAT', 'AAGACA', 'AAGAGA', 'AAGCAA', 'AAGGAA', 'AAGTAA', 'AATAAA', 'AATAAC', 'AATAAG', 'AATAAT', 'AATCAA', 'AATGAA', 'AATTAA', 'ACAAAA', 'ACAAAC', 'ACAAAG', 'ACAAAT', 'ACAACA', 'ACAAGA', 'ACAATA', 'ACACAA', 'ACAGAA', 'ACCAAA
AG', 'GTATAT', 'GTATCT', 'GTATGT', 'GTCTAT', 'GTGTAT', 'GTTATA', 'TAAATA', 'TAAATC', 'TAAATG', 'TAAATT', 'TAACTA', 'TAAGTA', 'TAATAT', 'TAATTA', 'TACACA', 'TACAGA', 'TACATA', 'TACATC', 'TACATG', 'TACATT', 'TACCTA', 'TACGTA', 'TACTTA', 'TAGACA', 'TAGAGA', 'TAGATA', 'TAGATC', 'TAGATG', 'TAGATT', 'TAGCTA', 'TAGGTA', 'TAGTTA', 'TATAAA', 'TATAAC', 'TATAAG', 'TATAAT', 'TATACA', 'TATACC', 'TATACG', 'TATACT', 'TATAGA', 'TATAGC', 'TATAGG', 'TATAGT', 'TATATA', 'TATATC', 'TATATG', 'TATATT', 'TATCAA', 'TATCCA', 'TATCGA', 'TATCTA', 'TATCTC', 'TATCTG', 'TATCTT', 'TATGAA', 'TATGCA', 'TATGGA', 'TATGTA', 'TATGTC', 'TATGTG', 'TATGTT', 'TATTAA', 'TATTCA', 'TATTGA', 'TATTTA', 'TATTTC', 'TATTTG', 'TCAATA', 'TCATAT', 'TCCATA', 'TCGATA', 'TCTAAA', 'TCTACA', 'TCTAGA', 'TCTATA', 'TCTATC', 'TCTATG', 'TCTATT', 'TCTCTA', 'TCTGTA', 'TGAATA', 'TGATAT', 'TGCATA', 'TGGATA', 'TGTAAA', 'TGTACA', 'TGTAGA', 'TGTATA', 'TGTATC', 'TGTATG', 'TGTATT', 'TGTCTA', 'TGTGTA', 'TTAAAT', 'TTAATA', 'TTACAT', 'TTAGAT', 'TTATAA', 'TTATAC', 'TTATAG', 'TTATAT', 'TTATCT', 'TTATGT', 'TTCATA', 'TTCTAT', 'TTGATA', 'TTGTAT', 'TTTAAA', 'TTTACA', 'TTTAGA', 'TTTATA', 'TTTATC', 'TTTATG')
#
# a_rich_d0 <- c('AAAAAA')
#
# a_rich_d1 <- c('AAAAAC', 'AAAAAG', 'AAAAAT', 'AAAACA', 'AAAAGA', 'AAAATA', 'AAACAA', 'AAAGAA', 'AAATAA', 'AACAAA', 'AAGAAA', 'AATAAA', 'ACAAAA', 'AGAAAA', 'ATAAAA', 'CAAAAA', 'GAAAAA', 'TAAAAA')
#
# a_rich_d2 <- c('AAAACC', 'AAAACG', 'AAAACT', 'AAAAGC', 'AAAAGG', 'AAAAGT', 'AAAATC', 'AAAATG', 'AAAATT', 'AAACAC', 'AAACAG', 'AAACAT', 'AAACCA', 'AAACGA', 'AAACTA', 'AAAGAC', 'AAAGAG', 'AAAGAT', 'AAAGCA', 'AAAGGA', 'AAAGTA', 'AAATCA', 'AAATGA', 'AAATTA', 'AACAAC', 'AACAAG', 'AACAAT', 'AACACA', 'AACAGA', 'AACCAA', 'AACGAA', 'AACTAA', 'AAGAAC', 'AAGAAG', 'AAGAAT', 'AAGACA', 'AAGAGA', 'AAGCAA', 'AAGGAA', 'AAGTAA', 'AATAAC', 'AATAAG', 'AATAAT', 'AATCAA', 'AATGAA', 'AATTAA', 'ACAAAC', 'ACAAAG', 'ACAAAT', 'ACAACA', 
T', 'TTGGTT', 'TTGTCT', 'TTGTGT', 'TTGTTA', 'TTGTTC', 'TTGTTG', 'TTTAAT', 'TTTACT', 'TTTAGT', 'TTTCAT', 'TTTCCT', 'TTTCGT', 'TTTCTA', 'TTTCTC', 'TTTCTG', 'TTTGAT', 'TTTGCT', 'TTTGGT', 'TTTGTA', 'TTTGTC', 'TTTGTG', 'TTTTAA', 'TTTTAC', 'TTTTAG', 'TTTTCA', 'TTTTCC', 'TTTTCG', 'TTTTGA', 'TTTTGC', 'TTTTGG')
#
# tata_rich_d0 <- c('ATATAT', 'TATATA')
#
# tata_rich_d1 <- c('AAATAT', 'AATATA', 'ACATAT', 'AGATAT', 'ATAAAT', 'ATACAT', 'ATAGAT', 'ATATAA', 'ATATAC', 'ATATAG', 'ATATCT', 'ATATGT', 'ATATTT', 'ATCTAT', 'ATGTAT', 'ATTTAT', 'CATATA', 'CTATAT', 'GATATA', 'GTATAT', 'TAAATA', 'TACATA', 'TAGATA', 'TATAAA', 'TATACA', 'TATAGA', 'TATATC', 'TATATG', 'TATATT', 'TATCTA', 'TATGTA', 'TATTTA', 'TCTATA', 'TGTATA', 'TTATAT', 'TTTATA')
#
# tata_rich_d2 <- c('AAATAC', 'AAATAG', 'AAATCT', 'AAATGT', 'AAATTT', 'AACATA', 'AACTAT', 'AAGATA', 'AAGTAT', 'AATACA', 'AATAGA', 'AATATC', 'AATATG', 'AATATT', 'AATCTA', 'AATGTA', 'AATTAT', 'AATTTA', 'ACACAT', 'ACAGAT', 'ACATAA', 'ACATAC', 'ACATAG', 'ACATCT', 'ACATGT', 'ACATTT', 'ACCTAT', 'ACGTAT', 'ACTATA', 'ACTTAT', 'AGACAT', 'AGAGAT', 'AGATAA', 'AGATAC', 'AGATAG', 'AGATCT', 'AGATGT', 'AGATTT', 'AGCTAT', 'AGGTAT', 'AGTATA', 'AGTTAT', 'ATAAAC', 'ATAAAG', 'ATAACT', 'ATAAGT', 'ATAATT', 'ATACAA', 'ATACAC', 'ATACAG', 'ATACCT', 'ATACGT', 'ATACTT', 'ATAGAA', 'ATAGAC', 'ATAGAG', 'ATAGCT', 'ATAGGT', 'ATAGTT', 'ATATCA', 'ATATCC', 'ATATCG', 'ATATGA', 'ATATGC', 'ATATGG', 'ATATTA', 'ATATTC', 'ATATTG', 'ATCAAT', 'ATCCAT', 'ATCGAT', 'ATCTAA', 'ATCTAC', 'ATCTAG', 'ATCTCT', 'ATCTGT', 'ATGAAT', 'ATGCAT', 'ATGGAT', 'ATGTAA', 'ATGTAC', 'ATGTAG', 'ATGTCT', 'ATGTGT', 'ATTAAT', 'ATTATA', 'ATTCAT', 'ATTGAT', 'ATTTAA', 'ATTTAC', 'ATTTAG', 'CAATAT', 'CACATA', 'CAGATA', 'CATACA', 'CATAGA', 'CATATC', 'CATATG', 'CATATT', 'CATCTA', 'CATGTA', 'CATTTA', 'CCATAT', 'CCTATA', 'CGATAT', 'CGTATA', 'CTAAAT', 'CTACAT', 'CTAGAT', 'CTATAA', 'CTATAC', 'CTATAG', 'CTATCT', 'CTATGT', 'CTCTAT', 'CTGTAT', 'CTTATA', 'GAATAT', 'GACATA', 'GAGATA', 'GATACA', 'GATAGA', 'GATATC', 'GATATG', 'GATATT', 'GATCTA', 'GATGTA', 'GATTTA', 'GCATAT', 'GCTATA', 'GGATAT', 'GGTATA', 'GTAAAT', 'GTACAT', 'GTAGAT', 'GTATAA', 'GTATAC', 'GTATAG', 'GTATCT', 'GTATGT', 'GTCTAT', 'GTGTAT', 'GTTATA', 'TAAATC', 'TAAATG', 'TAAATT', 'TAACTA', 'TAAGTA', 'TAATAT', 'TAATTA', 'TACACA', 'TACAGA', 'TACATC', 'TACATG', 'TACATT', 'TACCTA', 'TACGTA', 'TACTTA', 'TAGACA', 'TAGAGA', 'TAGATC', 'TAGATG', 'TAGATT', 'TAGCTA', 'TAGGTA', 'TAGTTA', 'TATAAC', 'TATAAG', 'TATAAT', 'TATACC', 'TATACG', 'TATACT', 'TATAGC', 'TATAGG', 'TATAGT', 'TATCAA', 'TATCCA', 'TATCGA', 'TATCTC', 'TATCTG', 'TATCTT', 'TATGAA', 'TATGCA', 'TATGGA', 'TATGTC', 'TATGTG', 'TATGTT', 'TATTAA', 'TATTCA', 'TATTGA', 'TATTTC', 'TATTTG', 'TCAATA', 'TCATAT', 'TCCATA', 'TCGATA', 'TCTAAA', 'TCTACA', 'TCTAGA', 'TCTATC', 'TCTATG', 'TCTATT', 'TCTCTA', 'TCTGTA', 'TGAATA', 'TGATAT', 'TGCATA', 'TGGATA', 'TGTAAA', 'TGTACA', 'TGTAGA', 'TGTATC', 'TGTATG', 'TGTATT', 'TGTCTA', 'TGTGTA', 'TTAAAT', 'TTAATA', 'TTACAT', 'TTAGAT', 'TTATAA', 'TTATAC', 'TTATAG', 'TTATCT', 'TTATGT', 'TTCATA', 'TTCTAT', 'TTGATA', 'TTGTAT', 'TTTAAA', 'TTTACA', 'TTTAGA', 'TTTATC', 'TTTATG')

# %% [markdown]
# #### 5mers

# %%
## Identify archetypical motifs and assign motifs to their most similar archetype

archetypes = np.asarray(['TATAT','ATATA','AAAAA','TTTTT'])

closest_family,closest_distance,closest_matches = zip(*[motifs.closest_archetype(motif, archetypes, kmer=5, max_mismatch=2) for motif in all_5mers])
closest_family   = np.asarray(closest_family)
closest_distance = np.asarray(closest_distance, dtype = float)

ambiguous_motifs = [h for h,m in zip(all_5mers, closest_matches) if len(m) > 1]


## Define family of TA/TA-rich motifs

fam_tatata_d0 = sorted(np.asarray(all_5mers)[((closest_family == 'TATAT') | (closest_family == 'ATATA')) & (closest_distance == 0)].tolist())
fam_tatata_d1 = sorted(np.asarray(all_5mers)[((closest_family == 'TATAT') | (closest_family == 'ATATA')) & (closest_distance == 1)].tolist())
fam_tatata_d2 = sorted(np.asarray(all_5mers)[((closest_family == 'TATAT') | (closest_family == 'ATATA')) & (closest_distance == 2)].tolist())

print(len(fam_tatata_d0), fam_tatata_d0[:5])
print(len(fam_tatata_d1), fam_tatata_d1[:5])
print(len(fam_tatata_d2), fam_tatata_d2[:5])


## Define family of A-rich motifs

fam_a_rich_d0 = sorted(np.asarray(all_5mers)[(closest_family == 'AAAAA') & (closest_distance == 0)].tolist())
fam_a_rich_d1 = sorted(np.asarray(all_5mers)[(closest_family == 'AAAAA') & (closest_distance == 1)].tolist())
fam_a_rich_d2 = sorted(np.asarray(all_5mers)[(closest_family == 'AAAAA') & (closest_distance == 2)].tolist())

print(len(fam_a_rich_d0), fam_a_rich_d0[:5])
print(len(fam_a_rich_d1), fam_a_rich_d1[:5])
print(len(fam_a_rich_d2), fam_a_rich_d2[:5])


## Define family of T-rich motifs

fam_t_rich_d0 = sorted(np.asarray(all_5mers)[(closest_family == 'TTTTT') & (closest_distance == 0)].tolist())
fam_t_rich_d1 = sorted(np.asarray(all_5mers)[(closest_family == 'TTTTT') & (closest_distance == 1)].tolist())
fam_t_rich_d2 = sorted(np.asarray(all_5mers)[(closest_family == 'TTTTT') & (closest_distance == 2)].tolist())

print(len(fam_t_rich_d0), fam_t_rich_d0[:5])
print(len(fam_t_rich_d1), fam_t_rich_d1[:5])
print(len(fam_t_rich_d2), fam_t_rich_d2[:5])


## Assign motifs to families based on priority

motif_priority = {
    
    'A-rich_d0'   : sorted(fam_a_rich_d0),
    'A-rich_d1'   : sorted(fam_a_rich_d1),
    'A-rich_d2'   : sorted(fam_a_rich_d2),
    'A-rich'      : sorted(fam_a_rich_d0 + fam_a_rich_d1 + fam_a_rich_d2),

    'T-rich_d0'   : sorted(fam_t_rich_d0),
    'T-rich_d1'   : sorted(fam_t_rich_d1),
    'T-rich_d2'   : sorted(fam_t_rich_d2),
    'T-rich'      : sorted(fam_t_rich_d0 + fam_t_rich_d1 + fam_t_rich_d2),
    
    'TA/TA-rich_d0' : sorted(fam_tatata_d0),
    'TA/TA-rich_d1' : sorted(fam_tatata_d1),
    'TA/TA-rich_d2' : sorted(fam_tatata_d2),
    'TA/TA-rich'    : sorted(fam_tatata_d0 + fam_tatata_d1 + fam_tatata_d2),
    
}

motif_family = {}
motif_hamming = {}

for motif in all_5mers:
    motif_family[motif] = 'Other'
    
for mf,mlist in motif_priority.items():
    for m in mlist:
        motif_family[m] = mf
        
for mf,mlist in motif_priority.items():
    for m in mlist:
        if ("_d") in mf:
            motif_hamming[m] = mf

            
## Output list of motifs in each family for use in R

motif_unique = {}

for mf in motif_priority.keys():
    motif_unique[mf] = sorted([k for k,v in motif_family.items() if (v == mf)])
    if ("_d" not in mf):
        print(mf, "\t", len(motif_unique[mf]))
    
for mf,ml in motif_unique.items():
    if ("_d" not in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)


for mf,ml in motif_priority.items():
    if ("_d" in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)


## Record motif family definitions

hamming_definitions = {
    'priority'   : motif_priority,
    'family'     : motif_family,
    'no_overlap' : motif_unique,
    'hamming'    : motif_hamming,
}

with open(os.path.join(OUTDIR, 'motif_definitions.scer.5mers.distance.pickle'), mode = 'wb') as handle:
    pickle.dump(hamming_definitions, handle)
    
(pd.DataFrame.from_dict(motif_family, orient = 'index').reset_index()
 .rename(columns = {'index' : 'motif', 0 : 'family'})
 .to_csv(os.path.join(OUTDIR, 'motif_families.scer.5mers.distance.txt'))
)
# Out:
# Conflicting family assignment: AAATA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: AAATC equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: AAATG equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: AAATT equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: AACAT equidistant to ['TATAT' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: AACTA equidistant to ['ATATA' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: AAGAT equidistant to ['TATAT' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: AAGTA equidistant to ['ATATA' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: AATAC equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: AATAG equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: AATTA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: AATTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: ACACA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on priority
# Conflicting family assignment: ACAGA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on priority
# Conflicting family assignment: AGACA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on priority
# Conflicting family assignment: AGAGA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on priority
# Conflicting family assignment: ATAAA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATAAC equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATAAG equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATAAT equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATCAA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATCTT equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: ATGAA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATGTT equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: ATTAA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: ATTAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: ATTTC equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: ATTTG equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: CAAAT equidistant to ['TATAT' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: CAATA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: CATAA equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: CATTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: CTAAA equidistant to ['ATATA' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: CTATT equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: CTTAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: CTTTA equidistant to ['ATATA' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: GAAAT equidistant to ['TATAT' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: GAATA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: GATAA equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: GATTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: GTAAA equidistant to ['ATATA' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: GTATT equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: GTTAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: GTTTA equidistant to ['ATATA' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: TAAAC equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: TAAAG equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: TAATA equidistant to ['ATATA' 'AAAAA'] ... assigning to ATATA based on content
# Conflicting family assignment: TAATT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TACAA equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: TACTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TAGAA equidistant to ['TATAT' 'AAAAA'] ... assigning to TATAT based on content
# Conflicting family assignment: TAGTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TATTA equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TATTC equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TATTG equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TATTT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TCTCT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on priority
# Conflicting family assignment: TCTGT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on priority
# Conflicting family assignment: TGTCT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on priority
# Conflicting family assignment: TGTGT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on priority
# Conflicting family assignment: TTAAA equidistant to ['ATATA' 'AAAAA'] ... assigning to AAAAA based on content
# Conflicting family assignment: TTAAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TTATC equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: TTATG equidistant to ['ATATA' 'TTTTT'] ... assigning to ATATA based on content
# Conflicting family assignment: TTCAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: TTCTA equidistant to ['ATATA' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: TTGAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: TTGTA equidistant to ['ATATA' 'TTTTT'] ... assigning to TTTTT based on content
# Conflicting family assignment: TTTAA equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TTTAC equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TTTAG equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# Conflicting family assignment: TTTAT equidistant to ['TATAT' 'TTTTT'] ... assigning to TATAT based on content
# 2 ['ATATA', 'TATAT']
# 30 ['AAATA', 'AATAT', 'ACATA', 'AGATA', 'ATAAA']
# 146 ['AAATC', 'AAATG', 'AAATT', 'AATAC', 'AATAG']
# 1 ['AAAAA']
# 13 ['AAAAC', 'AAAAG', 'AAAAT', 'AAACA', 'AAAGA']
# 57 ['AAACC', 'AAACG', 'AAACT', 'AAAGC', 'AAAGG']
# 1 ['TTTTT']
# 13 ['ATTTT', 'CTTTT', 'GTTTT', 'TCTTT', 'TGTTT']
# 57 ['AATTT', 'ACTTT', 'AGTTT', 'ATTCT', 'ATTGT']
# A-rich 	 71
# T-rich 	 71
# TA/TA-rich 	 178
# a_rich <- c('AAAAA', 'AAAAC', 'AAAAG', 'AAAAT', 'AAACA', 'AAACC', 'AAACG', 'AAACT', 'AAAGA', 'AAAGC', 'AAAGG', 'AAAGT', 'AACAA', 'AACAC', 'AACAG', 'AACAT', 'AACCA', 'AACGA', 'AACTA', 'AAGAA', 'AAGAC', 'AAGAG', 'AAGAT', 'AAGCA', 'AAGGA', 'AAGTA', 'AATAA', 'AATCA', 'AATGA', 'ACAAA', 'ACAAC', 'ACAAG', 'ACAAT', 'ACCAA', 'ACGAA', 'ACTAA', 'AGAAA', 'AGAAC', 'AGAAG', 'AGAAT', 'AGCAA', 'AGGAA', 'AGTAA', 'CAAAA', 'CAAAC', 'CAAAG', 'CAAAT', 'CAACA', 'CAAGA', 'CACAA', 'CAGAA', 'CCAAA', 'CGAAA', 'CTAAA', 'GAAAA', 'GAAAC', 'GAAAG', 'GAAAT', 'GAACA', 'GAAGA', 'GACAA', 'GAGAA', 'GCAAA', 'GGAAA', 'GTAAA', 'TAAAA', 'TAACA', 'TAAGA', 'TCAAA', 'TGAAA', 'TTAAA')
#
# t_rich <- c('AATTT', 'ACTTT', 'AGTTT', 'ATTCT', 'ATTGT', 'ATTTT', 'CATTT', 'CCTTT', 'CGTTT', 'CTCTT', 'CTGTT', 'CTTCT', 'CTTGT', 'CTTTA', 'CTTTC', 'CTTTG', 'CTTTT', 'GATTT', 'GCTTT', 'GGTTT', 'GTCTT', 'GTGTT', 'GTTCT', 'GTTGT', 'GTTTA', 'GTTTC', 'GTTTG', 'GTTTT', 'TCATT', 'TCCTT', 'TCGTT', 'TCTTA', 'TCTTC', 'TCTTG', 'TCTTT', 'TGATT', 'TGCTT', 'TGGTT', 'TGTTA', 'TGTTC', 'TGTTG', 'TGTTT', 'TTACT', 'TTAGT', 'TTATT', 'TTCAT', 'TTCCT', 'TTCGT', 'TTCTA', 'TTCTC', 'TTCTG', 'TTCTT', 'TTGAT', 'TTGCT', 'TTGGT', 'TTGTA', 'TTGTC', 'TTGTG', 'TTGTT', 'TTTCA', 'TTTCC', 'TTTCG', 'TTTCT', 'TTTGA', 'TTTGC', 'TTTGG', 'TTTGT', 'TTTTA', 'TTTTC', 'TTTTG', 'TTTTT')
#
# tata_rich <- c('AAATA', 'AAATC', 'AAATG', 'AAATT', 'AATAC', 'AATAG', 'AATAT', 'AATCT', 'AATGT', 'AATTA', 'ACACA', 'ACAGA', 'ACATA', 'ACATC', 'ACATG', 'ACATT', 'ACCTA', 'ACGTA', 'ACTAT', 'ACTTA', 'AGACA', 'AGAGA', 'AGATA', 'AGATC', 'AGATG', 'AGATT', 'AGCTA', 'AGGTA', 'AGTAT', 'AGTTA', 'ATAAA', 'ATAAC', 'ATAAG', 'ATAAT', 'ATACA', 'ATACC', 'ATACG', 'ATACT', 'ATAGA', 'ATAGC', 'ATAGG', 'ATAGT', 'ATATA', 'ATATC', 'ATATG', 'ATATT', 'ATCAA', 'ATCCA', 'ATCGA', 'ATCTA', 'ATCTC', 'ATCTG', 'ATCTT', 'ATGAA', 'ATGCA', 'ATGGA', 'ATGTA', 'ATGTC', 'ATGTG', 'ATGTT', 'ATTAA', 'ATTAT', 'ATTCA', 'ATTGA', 'ATTTA', 'ATTTC', 'ATTTG', 'CAATA', 'CACAT', 'CAGAT', 'CATAA', 'CATAC', 'CATAG', 'CATAT', 'CATCT', 'CATGT', 'CCATA', 'CCTAT', 'CGATA', 'CGTAT', 'CTACA', 'CTAGA', 'CTATA', 'CTATC', 'CTATG', 'CTATT', 'CTCTA', 'CTGTA', 'CTTAT', 'GAATA', 'GACAT', 'GAGAT', 'GATAA', 'GATAC', 'GATAG', 'GATAT', 'GATCT', 'GATGT', 'GCATA', 'GCTAT', 'GGATA', 'GGTAT', 'GTACA', 'GTAGA', 'GTATA', 'GTATC', 'GTATG', 'GTATT', 'GTCTA', 'GTGTA', 'GTTAT', 'TAAAC', 'TAAAG', 'TAAAT', 'TAACT', 'TAAGT', 'TAATA', 'TAATT', 'TACAA', 'TACAC', 'TACAG', 'TACAT', 'TACCT', 'TACGT', 'TACTT', 'TAGAA', 'TAGAC', 'TAGAG', 'TAGAT', 'TAGCT', 'TAGGT', 'TAGTT', 'TATAA', 'TATAC', 'TATAG', 'TATAT', 'TATCA', 'TATCC', 'TATCG', 'TATCT', 'TATGA', 'TATGC', 'TATGG', 'TATGT', 'TATTA', 'TATTC', 'TATTG', 'TATTT', 'TCAAT', 'TCATA', 'TCCAT', 'TCGAT', 'TCTAA', 'TCTAC', 'TCTAG', 'TCTAT', 'TCTCT', 'TCTGT', 'TGAAT', 'TGATA', 'TGCAT', 'TGGAT', 'TGTAA', 'TGTAC', 'TGTAG', 'TGTAT', 'TGTCT', 'TGTGT', 'TTAAT', 'TTACA', 'TTAGA', 'TTATA', 'TTATC', 'TTATG', 'TTTAA', 'TTTAC', 'TTTAG', 'TTTAT')
#
# a_rich_d0 <- c('AAAAA')
#
# a_rich_d1 <- c('AAAAC', 'AAAAG', 'AAAAT', 'AAACA', 'AAAGA', 'AACAA', 'AAGAA', 'AATAA', 'ACAAA', 'AGAAA', 'CAAAA', 'GAAAA', 'TAAAA')
#
# a_rich_d2 <- c('AAACC', 'AAACG', 'AAACT', 'AAAGC', 'AAAGG', 'AAAGT', 'AACAC', 'AACAG', 'AACAT', 'AACCA', 'AACGA', 'AACTA', 'AAGAC', 'AAGAG', 'AAGAT', 'AAGCA', 'AAGGA', 'AAGTA', 'AATCA', 'AATGA', 'ACAAC', 'ACAAG', 'ACAAT', 'ACCAA', 'ACGAA', 'ACTAA', 'AGAAC', 'AGAAG', 'AGAAT', 'AGCAA', 'AGGAA', 'AGTAA', 'CAAAC', 'CAAAG', 'CAAAT', 'CAACA', 'CAAGA', 'CACAA', 'CAGAA', 'CCAAA', 'CGAAA', 'CTAAA', 'GAAAC', 'GAAAG', 'GAAAT', 'GAACA', 'GAAGA', 'GACAA', 'GAGAA', 'GCAAA', 'GGAAA', 'GTAAA', 'TAACA', 'TAAGA', 'TCAAA', 'TGAAA', 'TTAAA')
#
# t_rich_d0 <- c('TTTTT')
#
# t_rich_d1 <- c('ATTTT', 'CTTTT', 'GTTTT', 'TCTTT', 'TGTTT', 'TTATT', 'TTCTT', 'TTGTT', 'TTTCT', 'TTTGT', 'TTTTA', 'TTTTC', 'TTTTG')
#
# t_rich_d2 <- c('AATTT', 'ACTTT', 'AGTTT', 'ATTCT', 'ATTGT', 'CATTT', 'CCTTT', 'CGTTT', 'CTCTT', 'CTGTT', 'CTTCT', 'CTTGT', 'CTTTA', 'CTTTC', 'CTTTG', 'GATTT', 'GCTTT', 'GGTTT', 'GTCTT', 'GTGTT', 'GTTCT', 'GTTGT', 'GTTTA', 'GTTTC', 'GTTTG', 'TCATT', 'TCCTT', 'TCGTT', 'TCTTA', 'TCTTC', 'TCTTG', 'TGATT', 'TGCTT', 'TGGTT', 'TGTTA', 'TGTTC', 'TGTTG', 'TTACT', 'TTAGT', 'TTCAT', 'TTCCT', 'TTCGT', 'TTCTA', 'TTCTC', 'TTCTG', 'TTGAT', 'TTGCT', 'TTGGT', 'TTGTA', 'TTGTC', 'TTGTG', 'TTTCA', 'TTTCC', 'TTTCG', 'TTTGA', 'TTTGC', 'TTTGG')
#
# tata_rich_d0 <- c('ATATA', 'TATAT')
#
# tata_rich_d1 <- c('AAATA', 'AATAT', 'ACATA', 'AGATA', 'ATAAA', 'ATACA', 'ATAGA', 'ATATC', 'ATATG', 'ATATT', 'ATCTA', 'ATGTA', 'ATTTA', 'CATAT', 'CTATA', 'GATAT', 'GTATA', 'TAAAT', 'TACAT', 'TAGAT', 'TATAA', 'TATAC', 'TATAG', 'TATCT', 'TATGT', 'TATTT', 'TCTAT', 'TGTAT', 'TTATA', 'TTTAT')
#
# tata_rich_d2 <- c('AAATC', 'AAATG', 'AAATT', 'AATAC', 'AATAG', 'AATCT', 'AATGT', 'AATTA', 'ACACA', 'ACAGA', 'ACATC', 'ACATG', 'ACATT', 'ACCTA', 'ACGTA', 'ACTAT', 'ACTTA', 'AGACA', 'AGAGA', 'AGATC', 'AGATG', 'AGATT', 'AGCTA', 'AGGTA', 'AGTAT', 'AGTTA', 'ATAAC', 'ATAAG', 'ATAAT', 'ATACC', 'ATACG', 'ATACT', 'ATAGC', 'ATAGG', 'ATAGT', 'ATCAA', 'ATCCA', 'ATCGA', 'ATCTC', 'ATCTG', 'ATCTT', 'ATGAA', 'ATGCA', 'ATGGA', 'ATGTC', 'ATGTG', 'ATGTT', 'ATTAA', 'ATTAT', 'ATTCA', 'ATTGA', 'ATTTC', 'ATTTG', 'CAATA', 'CACAT', 'CAGAT', 'CATAA', 'CATAC', 'CATAG', 'CATCT', 'CATGT', 'CCATA', 'CCTAT', 'CGATA', 'CGTAT', 'CTACA', 'CTAGA', 'CTATC', 'CTATG', 'CTATT', 'CTCTA', 'CTGTA', 'CTTAT', 'GAATA', 'GACAT', 'GAGAT', 'GATAA', 'GATAC', 'GATAG', 'GATCT', 'GATGT', 'GCATA', 'GCTAT', 'GGATA', 'GGTAT', 'GTACA', 'GTAGA', 'GTATC', 'GTATG', 'GTATT', 'GTCTA', 'GTGTA', 'GTTAT', 'TAAAC', 'TAAAG', 'TAACT', 'TAAGT', 'TAATA', 'TAATT', 'TACAA', 'TACAC', 'TACAG', 'TACCT', 'TACGT', 'TACTT', 'TAGAA', 'TAGAC', 'TAGAG', 'TAGCT', 'TAGGT', 'TAGTT', 'TATCA', 'TATCC', 'TATCG', 'TATGA', 'TATGC', 'TATGG', 'TATTA', 'TATTC', 'TATTG', 'TCAAT', 'TCATA', 'TCCAT', 'TCGAT', 'TCTAA', 'TCTAC', 'TCTAG', 'TCTCT', 'TCTGT', 'TGAAT', 'TGATA', 'TGCAT', 'TGGAT', 'TGTAA', 'TGTAC', 'TGTAG', 'TGTCT', 'TGTGT', 'TTAAT', 'TTACA', 'TTAGA', 'TTATC', 'TTATG', 'TTTAA', 'TTTAC', 'TTTAG')

# %% [markdown]
# #### 4mers

# %%
## Identify archetypical motifs and assign motifs to their most similar archetype

archetypes = np.asarray(['TATA','ATAT','AAAA','TTTT'])

closest_family,closest_distance,closest_matches = zip(*[motifs.closest_archetype(motif, archetypes, kmer=4, max_mismatch=2) for motif in all_4mers])
closest_family   = np.asarray(closest_family)
closest_distance = np.asarray(closest_distance, dtype = float)

ambiguous_motifs = [h for h,m in zip(all_4mers, closest_matches) if len(m) > 1]


## Define family of TA/TA-rich motifs

fam_tatata_d0 = sorted(np.asarray(all_4mers)[((closest_family == 'TATA') | (closest_family == 'ATAT')) & (closest_distance == 0)].tolist())
fam_tatata_d1 = sorted(np.asarray(all_4mers)[((closest_family == 'TATA') | (closest_family == 'ATAT')) & (closest_distance == 1)].tolist())
fam_tatata_d2 = sorted(np.asarray(all_4mers)[((closest_family == 'TATA') | (closest_family == 'ATAT')) & (closest_distance == 2)].tolist())

print(len(fam_tatata_d0), fam_tatata_d0[:5])
print(len(fam_tatata_d1), fam_tatata_d1[:5])
print(len(fam_tatata_d2), fam_tatata_d2[:5])


## Define family of A-rich motifs

fam_a_rich_d0 = sorted(np.asarray(all_4mers)[(closest_family == 'AAAA') & (closest_distance == 0)].tolist())
fam_a_rich_d1 = sorted(np.asarray(all_4mers)[(closest_family == 'AAAA') & (closest_distance == 1)].tolist())
fam_a_rich_d2 = sorted(np.asarray(all_4mers)[(closest_family == 'AAAA') & (closest_distance == 2)].tolist())

print(len(fam_a_rich_d0), fam_a_rich_d0[:5])
print(len(fam_a_rich_d1), fam_a_rich_d1[:5])
print(len(fam_a_rich_d2), fam_a_rich_d2[:5])


## Define family of T-rich motifs

fam_t_rich_d0 = sorted(np.asarray(all_4mers)[(closest_family == 'TTTT') & (closest_distance == 0)].tolist())
fam_t_rich_d1 = sorted(np.asarray(all_4mers)[(closest_family == 'TTTT') & (closest_distance == 1)].tolist())
fam_t_rich_d2 = sorted(np.asarray(all_4mers)[(closest_family == 'TTTT') & (closest_distance == 2)].tolist())

print(len(fam_t_rich_d0), fam_t_rich_d0[:5])
print(len(fam_t_rich_d1), fam_t_rich_d1[:5])
print(len(fam_t_rich_d2), fam_t_rich_d2[:5])


## Assign motifs to families based on priority

motif_priority = {
    
    'A-rich_d0'   : sorted(fam_a_rich_d0),
    'A-rich_d1'   : sorted(fam_a_rich_d1),
    'A-rich_d2'   : sorted(fam_a_rich_d2),
    'A-rich'      : sorted(fam_a_rich_d0 + fam_a_rich_d1 + fam_a_rich_d2),

    'T-rich_d0'   : sorted(fam_t_rich_d0),
    'T-rich_d1'   : sorted(fam_t_rich_d1),
    'T-rich_d2'   : sorted(fam_t_rich_d2),
    'T-rich'      : sorted(fam_t_rich_d0 + fam_t_rich_d1 + fam_t_rich_d2),
    
    'TA/TA-rich_d0' : sorted(fam_tatata_d0),
    'TA/TA-rich_d1' : sorted(fam_tatata_d1),
    'TA/TA-rich_d2' : sorted(fam_tatata_d2),
    'TA/TA-rich'    : sorted(fam_tatata_d0 + fam_tatata_d1 + fam_tatata_d2),
    
}

motif_family = {}
motif_hamming = {}

for motif in all_4mers:
    motif_family[motif] = 'Other'
    
for mf,mlist in motif_priority.items():
    for m in mlist:
        motif_family[m] = mf
        
for mf,mlist in motif_priority.items():
    for m in mlist:
        if ("_d") in mf:
            motif_hamming[m] = mf


## Output list of motifs in each family for use in R

motif_unique = {}

for mf in motif_priority.keys():
    motif_unique[mf] = sorted([k for k,v in motif_family.items() if (v == mf)])
    if ("_d" not in mf):
        print(mf, "\t", len(motif_unique[mf]))
    
for mf,ml in motif_unique.items():
    if ("_d" not in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)

for mf,ml in motif_priority.items():
    if ("_d" in mf):
        outstring = "\n" + mf.replace("-","_").replace("/","").lower() + " <- c('" + "', '".join(ml) + "')"
        print(outstring)


## Record motif family definitions

hamming_definitions = {
    'priority'   : motif_priority,
    'family'     : motif_family,
    'no_overlap' : motif_unique,
    'hamming'    : motif_hamming,
}

with open(os.path.join(OUTDIR, 'motif_definitions.scer.4mers.distance.pickle'), mode = 'wb') as handle:
    pickle.dump(hamming_definitions, handle)

(pd.DataFrame.from_dict(motif_family, orient = 'index').reset_index()
 .rename(columns = {'index' : 'motif', 0 : 'family'})
 .to_csv(os.path.join(OUTDIR, 'motif_families.scer.4mers.distance.txt'))
)
# Out:
# Conflicting family assignment: AAAT equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: AACT equidistant to ['ATAT' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: AAGT equidistant to ['ATAT' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: AATA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: AATC equidistant to ['TATA' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: AATG equidistant to ['TATA' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: AATT equidistant to ['TATA' 'ATAT' 'AAAA' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: ACAC equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on priority
# Conflicting family assignment: ACAG equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on priority
# Conflicting family assignment: ACTA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: ACTT equidistant to ['ATAT' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: AGAC equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on priority
# Conflicting family assignment: AGAG equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on priority
# Conflicting family assignment: AGTA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: AGTT equidistant to ['ATAT' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: ATAA equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: ATCA equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: ATGA equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: ATTA equidistant to ['TATA' 'ATAT' 'AAAA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: ATTC equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: ATTG equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: ATTT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: CAAT equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: CACA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on priority
# Conflicting family assignment: CAGA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on priority
# Conflicting family assignment: CATT equidistant to ['TATA' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: CTAA equidistant to ['ATAT' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: CTCT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on priority
# Conflicting family assignment: CTGT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on priority
# Conflicting family assignment: CTTA equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: GAAT equidistant to ['ATAT' 'AAAA'] ... assigning to ATAT based on content
# Conflicting family assignment: GACA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on priority
# Conflicting family assignment: GAGA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on priority
# Conflicting family assignment: GATT equidistant to ['TATA' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: GTAA equidistant to ['ATAT' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: GTCT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on priority
# Conflicting family assignment: GTGT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on priority
# Conflicting family assignment: GTTA equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TAAA equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: TAAC equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: TAAG equidistant to ['TATA' 'AAAA'] ... assigning to TATA based on content
# Conflicting family assignment: TAAT equidistant to ['TATA' 'ATAT' 'AAAA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TACT equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TAGT equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TATT equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TCAA equidistant to ['TATA' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: TCAT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: TCTC equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on priority
# Conflicting family assignment: TCTG equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on priority
# Conflicting family assignment: TGAA equidistant to ['TATA' 'AAAA'] ... assigning to AAAA based on content
# Conflicting family assignment: TGAT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: TGTC equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on priority
# Conflicting family assignment: TGTG equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on priority
# Conflicting family assignment: TTAA equidistant to ['TATA' 'ATAT' 'AAAA' 'TTTT'] ... assigning to TATA based on content
# Conflicting family assignment: TTAC equidistant to ['ATAT' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: TTAG equidistant to ['ATAT' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: TTAT equidistant to ['ATAT' 'TTTT'] ... assigning to ATAT based on content
# Conflicting family assignment: TTCA equidistant to ['TATA' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: TTGA equidistant to ['TATA' 'TTTT'] ... assigning to TTTT based on content
# Conflicting family assignment: TTTA equidistant to ['TATA' 'TTTT'] ... assigning to TATA based on content
# 2 ['ATAT', 'TATA']
# 24 ['AAAT', 'AATA', 'ACAT', 'AGAT', 'ATAA']
# 68 ['AATT', 'ACAC', 'ACAG', 'ACCT', 'ACGT']
# 1 ['AAAA']
# 8 ['AAAC', 'AAAG', 'AACA', 'AAGA', 'ACAA']
# 24 ['AACC', 'AACG', 'AACT', 'AAGC', 'AAGG']
# 1 ['TTTT']
# 8 ['CTTT', 'GTTT', 'TCTT', 'TGTT', 'TTCT']
# 24 ['ACTT', 'AGTT', 'CATT', 'CCTT', 'CGTT']
# A-rich 	 33
# T-rich 	 33
# TA/TA-rich 	 94
#
# a_rich <- c('AAAA', 'AAAC', 'AAAG', 'AACA', 'AACC', 'AACG', 'AACT', 'AAGA', 'AAGC', 'AAGG', 'AAGT', 'AATC', 'AATG', 'ACAA', 'ACCA', 'ACGA', 'AGAA', 'AGCA', 'AGGA', 'CAAA', 'CAAC', 'CAAG', 'CCAA', 'CGAA', 'CTAA', 'GAAA', 'GAAC', 'GAAG', 'GCAA', 'GGAA', 'GTAA', 'TCAA', 'TGAA')
#
# t_rich <- c('ACTT', 'AGTT', 'CATT', 'CCTT', 'CGTT', 'CTTC', 'CTTG', 'CTTT', 'GATT', 'GCTT', 'GGTT', 'GTTC', 'GTTG', 'GTTT', 'TCCT', 'TCGT', 'TCTT', 'TGCT', 'TGGT', 'TGTT', 'TTAC', 'TTAG', 'TTCA', 'TTCC', 'TTCG', 'TTCT', 'TTGA', 'TTGC', 'TTGG', 'TTGT', 'TTTC', 'TTTG', 'TTTT')
#
# tata_rich <- c('AAAT', 'AATA', 'AATT', 'ACAC', 'ACAG', 'ACAT', 'ACCT', 'ACGT', 'ACTA', 'AGAC', 'AGAG', 'AGAT', 'AGCT', 'AGGT', 'AGTA', 'ATAA', 'ATAC', 'ATAG', 'ATAT', 'ATCA', 'ATCC', 'ATCG', 'ATCT', 'ATGA', 'ATGC', 'ATGG', 'ATGT', 'ATTA', 'ATTC', 'ATTG', 'ATTT', 'CAAT', 'CACA', 'CAGA', 'CATA', 'CATC', 'CATG', 'CCAT', 'CCTA', 'CGAT', 'CGTA', 'CTAC', 'CTAG', 'CTAT', 'CTCT', 'CTGT', 'CTTA', 'GAAT', 'GACA', 'GAGA', 'GATA', 'GATC', 'GATG', 'GCAT', 'GCTA', 'GGAT', 'GGTA', 'GTAC', 'GTAG', 'GTAT', 'GTCT', 'GTGT', 'GTTA', 'TAAA', 'TAAC', 'TAAG', 'TAAT', 'TACA', 'TACC', 'TACG', 'TACT', 'TAGA', 'TAGC', 'TAGG', 'TAGT', 'TATA', 'TATC', 'TATG', 'TATT', 'TCAT', 'TCCA', 'TCGA', 'TCTA', 'TCTC', 'TCTG', 'TGAT', 'TGCA', 'TGGA', 'TGTA', 'TGTC', 'TGTG', 'TTAA', 'TTAT', 'TTTA')
#
# a_rich_d0 <- c('AAAA')
#
# a_rich_d1 <- c('AAAC', 'AAAG', 'AACA', 'AAGA', 'ACAA', 'AGAA', 'CAAA', 'GAAA')
#
# a_rich_d2 <- c('AACC', 'AACG', 'AACT', 'AAGC', 'AAGG', 'AAGT', 'AATC', 'AATG', 'ACCA', 'ACGA', 'AGCA', 'AGGA', 'CAAC', 'CAAG', 'CCAA', 'CGAA', 'CTAA', 'GAAC', 'GAAG', 'GCAA', 'GGAA', 'GTAA', 'TCAA', 'TGAA')
#
# t_rich_d0 <- c('TTTT')
#
# t_rich_d1 <- c('CTTT', 'GTTT', 'TCTT', 'TGTT', 'TTCT', 'TTGT', 'TTTC', 'TTTG')
#
# t_rich_d2 <- c('ACTT', 'AGTT', 'CATT', 'CCTT', 'CGTT', 'CTTC', 'CTTG', 'GATT', 'GCTT', 'GGTT', 'GTTC', 'GTTG', 'TCCT', 'TCGT', 'TGCT', 'TGGT', 'TTAC', 'TTAG', 'TTCA', 'TTCC', 'TTCG', 'TTGA', 'TTGC', 'TTGG')
#
# tata_rich_d0 <- c('ATAT', 'TATA')
#
# tata_rich_d1 <- c('AAAT', 'AATA', 'ACAT', 'AGAT', 'ATAA', 'ATAC', 'ATAG', 'ATCT', 'ATGT', 'ATTT', 'CATA', 'CTAT', 'GATA', 'GTAT', 'TAAA', 'TACA', 'TAGA', 'TATC', 'TATG', 'TATT', 'TCTA', 'TGTA', 'TTAT', 'TTTA')
#
# tata_rich_d2 <- c('AATT', 'ACAC', 'ACAG', 'ACCT', 'ACGT', 'ACTA', 'AGAC', 'AGAG', 'AGCT', 'AGGT', 'AGTA', 'ATCA', 'ATCC', 'ATCG', 'ATGA', 'ATGC', 'ATGG', 'ATTA', 'ATTC', 'ATTG', 'CAAT', 'CACA', 'CAGA', 'CATC', 'CATG', 'CCAT', 'CCTA', 'CGAT', 'CGTA', 'CTAC', 'CTAG', 'CTCT', 'CTGT', 'CTTA', 'GAAT', 'GACA', 'GAGA', 'GATC', 'GATG', 'GCAT', 'GCTA', 'GGAT', 'GGTA', 'GTAC', 'GTAG', 'GTCT', 'GTGT', 'GTTA', 'TAAC', 'TAAG', 'TAAT', 'TACC', 'TACG', 'TACT', 'TAGC', 'TAGG', 'TAGT', 'TCAT', 'TCCA', 'TCGA', 'TCTC', 'TCTG', 'TGAT', 'TGCA', 'TGGA', 'TGTC', 'TGTG', 'TTAA')
